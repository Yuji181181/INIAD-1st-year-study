# %%
import matplotlib.pyplot as plt
import math

# %%
principal = 10000
rate = 0.03
years = 20

# 年ごとの単利と複利の残高を計算するリスト
simple_interest = []  # 単利
compound_interest = []  # 複利
year_list = list(range(0, years + 1))  # 0年目から20年目までのリスト

for year in year_list:
    # 単利の計算: 元本 + (元本 * 金利 * 年数)
    simple_balance = principal * (1 + rate * year)
    simple_interest.append(simple_balance)
    
    # 複利の計算: 元本 * (1 + 金利) ^ 年数
    compound_balance = principal * (1 + rate) ** year
    compound_interest.append(compound_balance)

# グラフ描画
plt.plot(year_list, simple_interest, label="Simple", color='blue')
plt.plot(year_list, compound_interest, label="Compound", color='orange')

# グラフのタイトルとラベルを変更
plt.title("Simple and Compound interest")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()
