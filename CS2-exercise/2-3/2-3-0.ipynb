# %%
import matplotlib.pyplot as plt
import math

# %%
x_values = []
y_values = []
x = -10
while x <= 10:
    x_values.append(x)
    y_values.append(math.sin(x))
    x += 0.1

plt.plot(x_values, y_values, linestyle='-')
